# %% [markdown]
# <a href="https://colab.research.google.com/github/juanandres-montero/autoarima/blob/main/autoarima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pmdarima
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 19.6 MB/s eta 0:00:00

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb0c4cf5-b277-4095-adca-959790c05047" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb0c4cf5-b277-4095-adca-959790c05047">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
import statsmodels.api as sm
from pmdarima.arima import auto_arima

df_cpi = pd.read_stata(io.BytesIO(uploaded['cpi.dta'])) #Nombre de la base, en este caso lee .dta, puede cambiarse a Excel o CSV

y = df_cpi['cpi'] #Nombre de la variable
model = auto_arima(y,
                  trace=True,
                  seasonal=False,
                  max_p=5,
                  max_q=5,
                  d=1, # Número de diferencias para hacerse estacionaria
                  start_p=0,
                  start_q=0,
                  start_P=0,
                  start_Q=0,
                  D=0,
                  m=1,
                  information_criterion='aic',
                  stepwise=True)
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=325.137, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=281.744, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=278.490, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=356.014, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=276.497, Time=0.35 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=276.138, Time=0.18 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=274.338, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=276.188, Time=0.07 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=278.137, Time=0.34 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=287.216, Time=0.04 sec
#
# Best model:  ARIMA(2,1,0)(0,0,0)[0] intercept
# Total fit time: 1.236 seconds
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  158
# ...
